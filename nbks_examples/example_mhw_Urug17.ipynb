# %% [markdown]
# <a href="https://colab.research.google.com/github/francobarrionuevoenv21/MHW_xarray_mapping/blob/main/example_mhw_Urug17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/francobarrionuevoenv21/MHW_xarray_mapping.git
# Out:
# Cloning into 'MHW_xarray_mapping'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 66 (delta 33), reused 52 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (66/66), 7.93 MiB | 15.79 MiB/s, done.
# Resolving deltas: 100% (33/33), done.
