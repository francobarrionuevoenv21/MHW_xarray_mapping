# %%
from mhwMap import mapIntensityCat as micg
from mhwMap import mapIntensityCont as micn

# %%
PATH_SST = "sst_day_mean_1981-202502.nc"
MHW_DATE = "2024-10-25"

# %%
test = micg(PATH_SST, MHW_DATE)#.sst.plot()
# Out:
# [('1983-10-20', '1983-10-30'), ('1984-10-20', '1984-10-30'), ('1985-10-20', '1985-10-30'), ('1986-10-20', '1986-10-30'), ('1987-10-20', '1987-10-30'), ('1988-10-20', '1988-10-30'), ('1989-10-20', '1989-10-30'), ('1990-10-20', '1990-10-30'), ('1991-10-20', '1991-10-30'), ('1992-10-20', '1992-10-30'), ('1993-10-20', '1993-10-30'), ('1994-10-20', '1994-10-30'), ('1995-10-20', '1995-10-30'), ('1996-10-20', '1996-10-30'), ('1997-10-20', '1997-10-30'), ('1998-10-20', '1998-10-30'), ('1999-10-20', '1999-10-30'), ('2000-10-20', '2000-10-30'), ('2001-10-20', '2001-10-30'), ('2002-10-20', '2002-10-30'), ('2003-10-20', '2003-10-30'), ('2004-10-20', '2004-10-30'), ('2005-10-20', '2005-10-30'), ('2006-10-20', '2006-10-30'), ('2007-10-20', '2007-10-30'), ('2008-10-20', '2008-10-30'), ('2009-10-20', '2009-10-30'), ('2010-10-20', '2010-10-30'), ('2011-10-20', '2011-10-30'), ('2012-10-20', '2012-10-30')]
# ...

# %%
test['lon'] = test['lon']-360
test_02 = test.sel(lat=slice(-45, -20), lon=slice(-65, -35))

test_02.plot()

# %%
test_02.plot()

# %%
var02 = var02 + 5
print(var01)
# Out:
# 3
